# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing the dataset

# %%
df=pd.read_csv('tempYearly.csv')
df
# Out:
#     Temperature  Year  Rainfall
# 0         16.99  1956      1.01
# 1         10.34  1957      1.66
# 2         21.01  1958      3.50
# 3         23.68  1959      3.31
# 4         24.59  1960      3.61
# ..          ...   ...       ...
# 57        26.41  2013      1.50
# 58        11.24  2014      1.76
# 59        48.27  2015      6.73
# 60        20.29  2016      3.21
# 61        13.81  2017      2.00
#
# [62 rows x 3 columns]

# %% [markdown]
# ### Heatmap

# %%
sns.set(rc={'figure.figsize':(20,25)})
sns.jointplot("Temperature", "Rainfall", data=df)
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,25)})
sns.jointplot("Temperature", "Rainfall", data=df, kind="hex")
plt.show()

# %%
#Regression Plots
sns.set(rc={'figure.figsize':(20,25)})
sns.jointplot("Temperature", "Rainfall", data=df,kind='reg')
plt.show()
